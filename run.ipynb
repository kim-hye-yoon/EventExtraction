# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/event-extraction-dl
# Out:
# /content/drive/MyDrive/event-extraction-dl

# %%
! pip install pyvi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 62.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.4 MB/s eta 0:00:00
# ...

# %%
! python bilstm_joint_sentence2_.py --num_epochs 20 --use_pretrained --use_postag
# Out:
# Namespace(no_train=False, train_batch_size=8, eval_batch_size=8, lr=0.001, num_epochs=20, log_step=100, no_cuda=False, word_embedding_dim=300, use_pretrained=True, use_postag=True, postag_embedding_dim=25, hidden_size=512, dropout_rate=0.5)
# Epoch 1|20:
# Batch 1|1608: loss 6.8950 | Event detection: f1 0.00 precision 0.00 recall 0.00 | Argument detection: f1 0.00 precision 0.00 recall 0.00
# Batch 101|1608: loss 0.4834 | Event detection: f1 0.00 precision 0.00 recall 0.00 | Argument detection: f1 0.00 precision 0.00 recall 0.00
# Batch 201|1608: loss 0.2634 | Event detection: f1 0.00 precision 0.00 recall 0.00 | Argument detection: f1 0.00 precision 0.00 recall 0.00
# Batch 301|1608: loss 0.8446 | Event detection: f1 0.00 precision 0.00 recall 0.00 | Argument detection: f1 0.00 precision 0.00 recall 0.00
# Batch 401|1608: loss 0.2318 | Event detection: f1 0.00 precision 0.00 recall 0.00 | Argument detection: f1 0.00 precision 0.00 recall 0.00
# ...
